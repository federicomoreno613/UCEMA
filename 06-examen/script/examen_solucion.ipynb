# %%
import pandas as pd

# %%
cd script/
# Out:
# [Errno 2] No such file or directory: 'script/'
# /Users/usuario/PycharmProjects/pythonProject5/UCEMA/06-examen/script

# %%
path_file = "..//fuentes/recibos_facts_debitos.csv"

# %%
df = pd.read_csv(path_file, index_col=0)

# %% [markdown]
# ## 1- Cuáles son las características principales del DF?
# a- Cantidad de rows y columnas.
# b- Clases de datos

# %%
print(f" El dataframe es un excel con recibos cobrados. En el dataset hay {df.shape[0]} filas y {df.shape[1]}.los tipos de datos por columnas son {df.dtypes}")
# Out:
#  El dataframe es un excel con recibos cobrados. En el dataset hay 41334 filas y 4.los tipos de datos por columnas son Nro Comprobante     object
# Fecha               object
# Total              float64
# ID_cliente         float64
# dtype: object

# %% [markdown]
# ## 2. El dataset cuenta con datos faltantes?
# a- Muestre la cantidad de faltantes por columnas

# %%
df.isna().sum()
# Out:
# Nro Comprobante    0
# Fecha              0
# Total              3
# ID_cliente         4
# dtype: int64

# %% [markdown]
# b-Que porcentaje de faltantes hay

# %%
df.isna().sum()/len(df)
# Out:
# Nro Comprobante    0.000000
# Fecha              0.000000
# Total              0.000073
# ID_cliente         0.000097
# dtype: float64

# %% [markdown]
# c-Sí hay faltantes, cómo procederán a hacer el tratamiento de los mismos?

# %%
df[df.Total.isna()]
# Out:
#           Nro Comprobante       Fecha  Total  ID_cliente
# 41330  REC X0099-00006794  2014-09-04    NaN         NaN
# 41331  REC X0099-00006794  2014-09-04    NaN         NaN
# 41333  REC X0099-00006794  2022-09-04    NaN         NaN

# %%
df[df.ID_cliente.isna()]
# Out:
#           Nro Comprobante       Fecha       Total  ID_cliente
# 41330  REC X0099-00006794  2014-09-04         NaN         NaN
# 41331  REC X0099-00006794  2014-09-04         NaN         NaN
# 41333  REC X0099-00006794  2022-09-04         NaN         NaN
# 41334  REC X0099-00006794  2022-03-01  10000000.0         NaN

# %% [markdown]
# Se observa valores nulos en 3 muestras de total, todas se corresponden con valores nulos de ID de cliente. También hay un valor en ID_cliente nulo con un valor atípico en la columna Total

# %%
df.Fecha = pd.to_datetime(df.Fecha)

# %%
filtro = df.Fecha > "2014-09-04"
minimo_exceptuando_nulos = df[filtro]["Fecha"].min()
minimo_exceptuando_nulos
# Out:
# Timestamp('2015-12-10 00:00:00')

# %%
dias_diferencia = (df[filtro]["Fecha"].min() -  df["Fecha"].min()).days

# %%
total_de_la_muestra = len(df)
cant_casos_fecha_mayor = (df.Fecha > "2014-09-04").sum()
porcentaje_casos = cant_casos_fecha_mayor/total_de_la_muestra

print(f"En el caso de los nulos. Observamos que en el caso del Total dos casos tienen una fecha igual a 2014-09-04 y La fecha siguiente a esa fecha minima es {minimo_exceptuando_nulos} correspondiente a {minimo_exceptuando_nulos - df.Fecha.min()} días de diferencia. Siendo posiblemente un valor mal imputado. Teniendo en cuenta todos los nulos observamos que hay un total de {total_de_la_muestra}. Es decir {df.Total.isna().sum()} casos de total es nulo y {df.ID_cliente.isna().sum()} donde el ID de cliente es nulo. Entotal representan el {porcentaje_casos*100:.5f}  % del total del dataset. Observando los casos donde Total es nulo se puede analizar que es un valor atípico. Por lo tanto es una buena decisión eliminar valores nulos y no reemplazarlos")
# Out:
# En el caso de los nulos. Observamos que en el caso del Total dos casos tienen una fecha igual a 2014-09-04 y La fecha siguiente a esa fecha minima es 2015-12-10 00:00:00 correspondiente a 462 days 00:00:00 días de diferencia. Siendo posiblemente un valor mal imputado. Teniendo en cuenta todos los nulos observamos que hay un total de 41334. Es decir 3 casos de total es nulo y 4 donde el ID de cliente es nulo. Entotal representan el 99.99516  % del total del dataset. Observando los casos donde Total es nulo se puede analizar que es un valor atípico. Por lo tanto es una buena decisión eliminar valores nulos y no reemplazarlos

# %% [markdown]
# ## 3.Imprima las estadísticas básicas del dataset.
# Hay un método para eso tanto en python cómo en R (count, mean, 25%,etc)

# %%
df.describe().round()
# Out:
#             Total  ID_cliente
# count     41331.0     41330.0
# mean       1302.0       483.0
# std       49200.0       275.0
# min           0.0         0.0
# 25%         331.0       242.0
# 50%         999.0       476.0
# 75%        1000.0       733.0
# max    10000000.0       964.0

# %%
maximo_original = df["Total"].max()
filtro = df.Total < 10000000.0
maximo_siguiente = df[filtro]["Total"].max()

# %%
(maximo_original - maximo_siguiente)/maximo_siguiente
# Out:
# 177.57142857142858

# %% [markdown]
# ## 4.¿Qué es un dato outlier? ¿Cómo procedería al análisis del mismo?
# Un dato outliers es un dato que está fuera de la distribución de una variable. Muchas veces los valores outliers pueden ser datos mal imputados pero otras veces pueden aportar información importante sobre el caso. Por ejemplo en un caso de Fraude, los casos outliers pueden significar un patrón a analizar. En este dataset tenemos que el valor más cercano al valor máximo en el Valor Total a 10000000 es 56000 representando un 177% más respecto a este segundo valor.

# %%
df.nlargest(1, 'Total')
# Out:
#           Nro Comprobante      Fecha       Total  ID_cliente
# 41334  REC X0099-00006794 2022-03-01  10000000.0         NaN

# %%
df.nlargest(2, 'Total')
# Out:
#           Nro Comprobante      Fecha       Total  ID_cliente
# 41334  REC X0099-00006794 2022-03-01  10000000.0         NaN
# 33688  REC X0001-00004566 2020-06-30     56000.0       394.0

# %%
df.nlargest(3, 'Total')
# Out:
#           Nro Comprobante      Fecha       Total  ID_cliente
# 41334  REC X0099-00006794 2022-03-01  10000000.0         NaN
# 33688  REC X0001-00004566 2020-06-30     56000.0       394.0
# 33791  REC X0003-00000075 2020-07-31     53212.0       394.0

# %% [markdown]
# ## 5. Cambie el nombre de las columnas a "nro_comprobante", "fecha","monto","id_cliente"

# %%
df.columns = ["nro_comprobante", "fecha","monto","id_cliente"]

# %% [markdown]
# ## 6. ¿Cuantos clientes únicos hay en el dataset?

# %%
df.id_cliente.nunique()
# Out:
# 965

# %% [markdown]
# ## 7. Cree una nueva columna que llamada “tipo” que consista en agarrar la columna “nro_comprobante” y separar el primer string dejando sólo si es recibo, factura, nota de débito o nota de crédito.

# %%
df["tipo"] =df.nro_comprobante.apply(lambda x:x.split(" ")[0])

# %%
df.tipo.unique()
# Out:
# array(['FAC', 'N/C', 'N/D', 'REC'], dtype=object)

# %% [markdown]
# ## 8. Tipos de Comprobante.Responda.
# a- Cuantos registros se tienen de cada uno? (columna cantidad)
# b -monto total de los recibos (Columna suma monto)
# c- monto total de las notas de débito
# d- monto total de las notas de crédito
# e-monto total de lo facturado

# %%
df.groupby("tipo").agg(
    suma_monto =  ('monto', 'sum'),
    cantidad = ('monto', 'count')
)
# Out:
#        suma_monto  cantidad
# tipo
# FAC    7598706.46     10974
# N/C    1335102.12      2387
# N/D    8204046.41     15762
# REC   36693028.63     12208

# %% [markdown]
# 9. ¿Dé qué tipo de datos es la columna fecha? Pasarla a datetime
# Era de tipo object o string.

# %%
#opcion1
df["year"] = pd.to_datetime(df.fecha).dt.year
df["month"] = pd.to_datetime(df.fecha).dt.month
df['date'] = pd.to_datetime(df[['year', 'month']].assign(DAY=1))
df['date']
# Out:
# 0       2015-12-01
# 1       2015-12-01
# 2       2015-12-01
# 3       2015-12-01
# 4       2015-12-01
#            ...
# 41329   2018-09-01
# 41330   2014-09-01
# 41331   2014-09-01
# 41333   2022-09-01
# 41334   2022-03-01
# Name: date, Length: 41334, dtype: datetime64[ns]

# %%
#opcion 2
df["year"] = pd.to_datetime(df.fecha).dt.year
df["month"] = pd.to_datetime(df.fecha).dt.month
df['year_month'] = df['year'].astype(str) + '-' + df['month'].astype(str)
df['year_month']
# Out:
# 0        2015-12
# 1        2015-12
# 2        2015-12
# 3        2015-12
# 4        2015-12
#           ...
# 41329     2018-9
# 41330     2014-9
# 41331     2014-9
# 41333     2022-9
# 41334     2022-3
# Name: year_month, Length: 41334, dtype: object

# %%
#opcion 3
pd.to_datetime(df["fecha"]).dt.to_period('M')
# Out:
# 0        2015-12
# 1        2015-12
# 2        2015-12
# 3        2015-12
# 4        2015-12
#           ...
# 41329    2018-09
# 41330    2014-09
# 41331    2014-09
# 41333    2022-09
# 41334    2022-03
# Name: fecha, Length: 41334, dtype: period[M]

# %% [markdown]
# ## 11- Sumar sólo lo cobrado (REC y N/D)
#  b- mostrar una tabla que tenga como indice fecha(año-mes) y columna monto_cobrado, cantidad_recibos. (group by)

# %%
filter_rec = (df["tipo"] == "REC") | (df["tipo"] == "N/D")
recibos_df = df[filter_rec]

# %%
#opcion 1
rec_mensual = recibos_df.groupby(["date"]).agg(
    suma_monto =  ('monto', 'sum'),
    cantidad = ('monto', 'count')
)
rec_mensual
# Out:
#              suma_monto  cantidad
# date
# 2014-09-01         0.00         0
# 2015-12-01      3339.00         4
# 2016-01-01     23217.27        24
# 2016-02-01     87138.09        61
# 2016-03-01    193843.65       158
# ...                 ...       ...
# 2022-03-01  10245495.68       210
# 2022-04-01    145510.59       148
# 2022-05-01     87518.58       106
# 2022-06-01     81386.59        88
# 2022-09-01         0.00         0
#
# [81 rows x 2 columns]

# %%
#opcion 2
def recibo(x):
    if x == "REC":
        return 1
    else:
        return 0
recibos_df["REC"] = recibos_df["tipo"].apply(recibo)
recibos_df.head()
# Out:
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/1287479126.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recibos_df["REC"] = recibos_df["tipo"].apply(recibo)
#           nro_comprobante      fecha   monto  id_cliente tipo  year  month  \
# 13361  N/D B0001-00000001 2016-01-12   66.16       536.0  N/D  2016      1
# 13362  N/D B0001-00000002 2016-01-28  110.54       838.0  N/D  2016      1
# 13363  N/D B0001-00000003 2016-02-05   16.46       536.0  N/D  2016      2
# 13364  N/D B0001-00000004 2016-02-11   83.10       838.0  N/D  2016      2
# 13365  N/D B0001-00000005 2016-02-16   49.99       801.0  N/D  2016      2
#
#             date year_month  REC
# 13361 2016-01-01     2016-1    0
# 13362 2016-01-01     2016-1    0
# 13363 2016-02-01     2016-2    0
# 13364 2016-02-01     2016-2    0
# 13365 2016-02-01     2016-2    0

# %%
recibos_df["REC"].unique()
# Out:
# array([0, 1])

# %%
#opcion 2
rec_mensual = recibos_df.groupby(["date"]).agg(
    suma_monto =  ('monto', 'sum'),
    cantidad = ('REC', 'sum')
)
rec_mensual
# Out:
#              suma_monto  cantidad
# date
# 2014-09-01         0.00         2
# 2015-12-01      3339.00         4
# 2016-01-01     23217.27        21
# 2016-02-01     87138.09        56
# 2016-03-01    193843.65       128
# ...                 ...       ...
# 2022-03-01  10245495.68        14
# 2022-04-01    145510.59        10
# 2022-05-01     87518.58         7
# 2022-06-01     81386.59         6
# 2022-09-01         0.00         1
#
# [81 rows x 2 columns]

# %%
#Opcion aburrida

# %%
df[df.tipo == "REC"]["monto"].sum()
# Out:
# 36693028.629999995

# %%
df[df.tipo == "N/D"]["monto"].sum()
# Out:
# 8204046.409999998

# %%
df[df.tipo == "FAC"]["monto"].sum()
# Out:
# 7598706.459999999

# %% [markdown]
# ## 12.¿Cuantos valores hay mayores a 60000 de la columna monto en el dataset general?

# %%
(df["monto"]>60000).sum()
# Out:
# 1

# %% [markdown]
# ## 13. ¿Cual es el valor máximo de la columna monto?  ¿Debería eliminarlo? ¿Por qué?  (en el dataset general)

# %%
df["monto"].max()
# Out:
# 10000000.0

# %%
df.nlargest(3, 'monto')
# Out:
#           nro_comprobante      fecha       monto  id_cliente tipo  year  \
# 41334  REC X0099-00006794 2022-03-01  10000000.0         NaN  REC  2022
# 33688  REC X0001-00004566 2020-06-30     56000.0       394.0  REC  2020
# 33791  REC X0003-00000075 2020-07-31     53212.0       394.0  REC  2020
#
#        month       date year_month
# 41334      3 2022-03-01     2022-3
# 33688      6 2020-06-01     2020-6
# 33791      7 2020-07-01     2020-7

# %% [markdown]
# Dado que tiene valores nulos en id_cliente y además representa un 177% más que el valor siguiente puedo justificar que es un valor mal imputado y por es lo eliminaría

# %% [markdown]
# ## 14.No tenga en cuenta el valor máximo para los siguientes análisis.

# %%
df = df[df["monto"]<df["monto"].max()]

filter_rec = (df["tipo"] == "REC") | (df["tipo"] == "N/D")
recibos_df = df[filter_rec]
recibos_df["REC"] = recibos_df["tipo"].apply(recibo)
rec_mensual = recibos_df.groupby(["date"]).agg(
    suma_monto =  ('monto', 'sum'),
    cantidad = ('REC', 'sum'),
    clientes_unicos = ('id_cliente', 'nunique')
)
# Out:
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/3344998958.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recibos_df["REC"] = recibos_df["tipo"].apply(recibo)

# %% [markdown]
# ## 15. en el total del dataset.
# Cuanto representa lo facturado sobre lo cobrado.
# Si sabe que lo facturado es el IVA ¿Tiene sentido? ¿Cómo lo interpretas?

# %%
df[df.tipo == "FAC"]["monto"].sum()/(df[df.tipo == "REC"]["monto"].sum() + df[df.tipo == "N/D"]["monto"].sum())
# Out:
# 0.2177462280517823

# %% [markdown]
# # 16. Dataset Dolar

# %% [markdown]
# Agregar dataset de dolar blue
# * 1- Cuáles son las características principales del DF?
# Cantidad de rows y columnas.
# Clases de datos
# * 2- El dataset cuenta con datos faltantes?
# Muestre la cantidad de faltantes por columnas
# Que porcentaje de faltantes hay
# Muestre las filas con datos faltantes
# Sí hay faltantes, ¿Cómo procederán a hacer el tratamiento de los mismos?
# Haga el tratamiento de los valores faltantes en caso de creerlo necesario.
# * 3- Imprima las estadísticas básicas del dataset. Hay un método para eso tanto en python cómo en R (count, mean, 25%,etc)

# %%
dolar_df = pd.read_csv("../fuentes/dolar_blue - Hoja 1.csv")

# %%
print(f" El dataframe es un excel con recibos cobrados. En el dataset hay {dolar_df.shape[0]} filas y {dolar_df.shape[1]}.los tipos de datos por columnas son {dolar_df.dtypes}")
# Out:
#  El dataframe es un excel con recibos cobrados. En el dataset hay 1763 filas y 3.los tipos de datos por columnas son Fecha     object
# Compra    object
# Venta     object
# dtype: object

# %%
dolar_df.isna().sum()
# Out:
# Fecha     0
# Compra    0
# Venta     0
# dtype: int64

# %%
dolar_df.describe()
# Out:
#              Fecha  Compra   Venta
# count         1763    1763    1763
# unique        1732     727     723
# top     31-08-2021  197,00  151,00
# freq             7      16      16

# %% [markdown]
# b- Pasar a datetime la columna Fechac
# c- Crear año mes

# %%
dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
dolar_df["year"] = pd.to_datetime(dolar_df.Fecha).dt.year
dolar_df["month"] = pd.to_datetime(dolar_df.Fecha).dt.month
dolar_df['date'] = pd.to_datetime(dolar_df[['year', 'month']].assign(DAY=1))
# Out:
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# ...
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '31-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '28-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '27-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '21-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '20-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '15-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '14-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '13-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '30-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '29-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '26-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '25-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '24-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '23-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '22-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '19-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '18-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '17-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)
# /var/folders/04/tp4wyrys03s5z6y1v720v3580000gn/T/ipykernel_1284/436113301.py:1: UserWarning: Parsing '16-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dolar_df["Fecha"] = pd.to_datetime(dolar_df.Fecha)

# %% [markdown]
# ## 17.Cree un dataset del valor promedio de la venta del dólar por año-mes (groupby). (fijarse ejercicio siguiente en caso de que no de nada de output)

# %%
dolar_df_mensual = dolar_df.groupby(["date"]).agg(
    media_venta =  ('Venta', 'mean')
)
dolar_df_mensual
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1587, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1586 try:
# -> 1587     result = self.grouper._cython_operation(
#    1588         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1589     )
#    1590 except NotImplementedError:
#    1591     # generally if we have numeric_only=False
#    1592     # and non-applicable functions
#    1593     # try to python agg
#    1594     # TODO: shouldn't min_count matter?
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938 ngroups = self.ngroups
# --> 939 return cy_op.cython_operation(
#     940     values=values,
#     941     axis=axis,
#     942     min_count=min_count,
#     943     comp_ids=ids,
#     944     ngroups=ngroups,
#     945     **kwargs,
#     946 )
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:626, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     618     return self._ea_wrap_cython_operation(
#     619         values,
#     620         min_count=min_count,
#    (...)
#     623         **kwargs,
#     624     )
# --> 626 return self._cython_op_ndim_compat(
#     627     values,
#     628     min_count=min_count,
#     629     ngroups=ngroups,
#     630     comp_ids=comp_ids,
#     631     mask=None,
#     632     **kwargs,
#     633 )
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:451, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     450     result_mask = result_mask[None, :]
# --> 451 res = self._call_cython_op(
#     452     values2d,
#     453     min_count=min_count,
#     454     ngroups=ngroups,
#     455     comp_ids=comp_ids,
#     456     mask=mask,
#     457     result_mask=result_mask,
#     458     **kwargs,
#     459 )
#     460 if res.shape[0] == 1:
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:516, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     515 out_shape = self._get_output_shape(ngroups, values)
# --> 516 func, values = self.get_cython_func_and_vals(values, is_numeric)
#     517 out_dtype = self.get_out_dtype(values.dtype)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:199, in WrappedCythonOp.get_cython_func_and_vals(self, values, is_numeric)
#     197     return func, values
# --> 199 func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     201 if values.dtype.kind in ["i", "u"]:
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:164, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     162 if "object" not in f.__signatures__:
#     163     # raise NotImplementedError here rather than TypeError later
# --> 164     raise NotImplementedError(
#     165         f"function is not implemented for this dtype: "
#     166         f"[how->{how},dtype->{dtype_str}]"
#     167     )
#     168 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '14,4915,8815,5113,55'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [176], in <cell line: 1>()
# ----> 1 dolar_df_mensual = dolar_df.groupby(["date"]).agg(
#       2     media_venta =  ('Venta', 'mean')
#       3 )
#       4 dolar_df_mensual
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/apply.py:481, in Apply.agg_dict_like(self)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
# --> 481     results = {
#     482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/apply.py:482, in <dictcomp>(.0)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
#     481     results = {
# --> 482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/generic.py:271, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
# --> 271     ret = self._aggregate_multiple_funcs(func)
#     272     if relabeling:
#     273         # error: Incompatible types in assignment (expression has type
#     274         # "Optional[List[str]]", variable has type "Index")
#     275         ret.columns = columns  # type: ignore[assignment]
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/generic.py:326, in SeriesGroupBy._aggregate_multiple_funcs(self, arg)
#     323 for idx, (name, func) in enumerate(arg):
#     325     key = base.OutputKey(label=name, position=idx)
# --> 326     results[key] = self.aggregate(func)
#     328 if any(isinstance(x, DataFrame) for x in results.values()):
#     329     from pandas import concat
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/generic.py:265, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     262     kwargs = {}
#     264 if isinstance(func, str):
# --> 265     return getattr(self, func)(*args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1965, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1963     return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    1964 else:
# -> 1965     result = self._cython_agg_general(
#    1966         "mean",
#    1967         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    1968         numeric_only=numeric_only_bool,
#    1969     )
#    1970     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1601, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count)
#    1597     return result
#    1599 # TypeError -> we may have an exception in trying to aggregate
#    1600 #  continue and exclude the block
# -> 1601 new_mgr = data.grouped_reduce(array_func, ignore_failures=True)
#    1603 if not is_ser and len(new_mgr) < len(data):
#    1604     warn_dropping_nuisance_columns_deprecated(type(self), how)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1595, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1587     result = self.grouper._cython_operation(
#    1588         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1589     )
#    1590 except NotImplementedError:
#    1591     # generally if we have numeric_only=False
#    1592     # and non-applicable functions
#    1593     # try to python agg
#    1594     # TODO: shouldn't min_count matter?
# -> 1595     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1597 return result
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1549, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1544     ser = df.iloc[:, 0]
#    1546 # We do not get here with UDFs, so we know that our dtype
#    1547 #  should always be preserved by the implemented aggregations
#    1548 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1549 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1551 if isinstance(values, Categorical):
#    1552     # Because we only get here with known dtype-preserving
#    1553     #  reductions, we cast back to Categorical.
#    1554     # TODO: if we ever get "rank" working, exclude it here.
#    1555     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:981, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     978     preserve_dtype = True
#     980 else:
# --> 981     result = self._aggregate_series_pure_python(obj, func)
#     983 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     984 if preserve_dtype:
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1005, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1003 for i, group in enumerate(splitter):
#    1004     group = group.__finalize__(obj, method="groupby")
# -> 1005     res = func(group)
#    1006     res = libreduction.extract_result(res)
#    1008     if not initialized:
#    1009         # We only do this validation on the first iteration
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1967, in GroupBy.mean.<locals>.<lambda>(x)
#    1963     return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    1964 else:
#    1965     result = self._cython_agg_general(
#    1966         "mean",
# -> 1967         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    1968         numeric_only=numeric_only_bool,
#    1969     )
#    1970     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/generic.py:11119, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11101 @doc(
#   11102     _num_doc,
#   11103     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11117     **kwargs,
#   11118 ):
# > 11119     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/generic.py:10689, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10681 def mean(
#   10682     self,
#   10683     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10687     **kwargs,
#   10688 ) -> Series | float:
# > 10689     return self._stat_function(
#   10690         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10691     )
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/generic.py:10641, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10631     warnings.warn(
#   10632         "Using the level keyword in DataFrame and Series aggregations is "
#   10633         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10636         stacklevel=find_stack_level(),
#   10637     )
#   10638     return self._agg_by_level(
#   10639         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10640     )
# > 10641 return self._reduce(
#   10642     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10643 )
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File ~/.conda/envs/pythonProject5/lib/python3.9/site-packages/pandas/core/nanops.py:1629, in _ensure_numeric(x)
#    1626             x = complex(x)
#    1627         except ValueError as err:
#    1628             # e.g. "foo"
# -> 1629             raise TypeError(f"Could not convert {x} to numeric") from err
#    1630 return x
#
# TypeError: Could not convert 14,4915,8815,5113,55 to numeric

# %% [markdown]
# ## 18. En python pase la columna Dolar Venta a Float.
#  (Hint en python dolar_df.Venta.apply(lambda x:x.replace(",",".")))

# %%
dolar_df.Venta = dolar_df.Venta.apply(lambda x:x.replace(",","."))

# %%
dolar_df.Venta = dolar_df.Venta.astype(float)

# %%
dolar_df_mensual = dolar_df.groupby(["date"]).agg(
    media_venta =  ('Venta', 'mean')
)
dolar_df_mensual
# Out:
#             media_venta
# date
# 2015-01-01    14.857500
# 2015-02-01    15.098000
# 2015-03-01    14.854000
# 2015-04-01    15.162500
# 2015-05-01    15.296667
# ...                 ...
# 2022-08-01   218.900000
# 2022-09-01   207.750000
# 2022-10-01   207.300000
# 2022-11-01   215.750000
# 2022-12-01   219.750000
#
# [96 rows x 1 columns]

# %% [markdown]
# ## 19.Cree un dataset que sea el resultado de hacer un merge/join entre el dataset agrupado de recibos_facts_debitos con el agrupado de dolar del punto anterior.
#  (Hint en python pd.merge(rec_mensual, dolar_df_mensual,how="left", left_index=True,right_index=True)

# %%
rec_mensual
# Out:
#             suma_monto  cantidad  clientes_unicos
# date
# 2015-12-01     3339.00         4                3
# 2016-01-01    23217.27        21               17
# 2016-02-01    87138.09        56               51
# 2016-03-01   193843.65       128              106
# 2016-04-01   208850.76       136              126
# ...                ...       ...              ...
# 2022-02-01   177288.65        16               44
# 2022-03-01   245495.68        13               41
# 2022-04-01   145510.59        10               35
# 2022-05-01    87518.58         7               30
# 2022-06-01    81386.59         6               24
#
# [79 rows x 3 columns]

# %%
df_mensual = pd.merge(rec_mensual, dolar_df_mensual,how="left", left_index=True,right_index=True)

# %%
len(df)
df_mensual
# Out:
#             suma_monto  cantidad  clientes_unicos  media_venta
# date
# 2015-12-01     3339.00         4                3    14.392667
# 2016-01-01    23217.27        21               17    14.732727
# 2016-02-01    87138.09        56               51    15.322632
# 2016-03-01   193843.65       128              106    15.280000
# 2016-04-01   208850.76       136              126    14.912727
# ...                ...       ...              ...          ...
# 2022-02-01   177288.65        16               44   210.892857
# 2022-03-01   245495.68        13               41   202.666667
# 2022-04-01   145510.59        10               35   206.058824
# 2022-05-01    87518.58         7               30   208.266667
# 2022-06-01    81386.59         6               24   222.382353
#
# [79 rows x 4 columns]

# %% [markdown]
# ## 25. Hacer un lineplot del total cobrado por año mes

# %%
df_mensual["suma_monto"].max()
# Out:
# 992573.34

# %%
df_mensual[["suma_monto"]].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 26.lineplot con clientes únicos por año mes en otro gráfico

# %%
df_mensual[["clientes_unicos"]].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 27. Poner ambas líneas en dos gráficos alineados en la misma columna

# %%
#df_mensual.reset_index(inplace=True)

# %%
# Destructuring initialization
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(14,5)) # axs is a (1,2) nd-array

# First subplot
axs[0].plot(df_mensual["clientes_unicos"], label="clientes únicos")
axs[0].set_title('Clientes unicos')
axs[0].legend()
# Second subplot
axs[1].plot(df_mensual["suma_monto"], label="Monto mensual", c='orange')
axs[1].set_title("Monto en pesos")
axs[1].legend()
# Global figure methods
plt.suptitle('Suma de monto vs clientes únicos')
plt.show()

# %% [markdown]
# ## 28. Haga otro gráfico que le parezca interesante. ¿Qué idea transmite con ese gráfico?

# %%
dolar_df_mensual
# Out:
#             media_venta
# date
# 2015-01-01    14.857500
# 2015-02-01    15.098000
# 2015-03-01    14.854000
# 2015-04-01    15.162500
# 2015-05-01    15.296667
# ...                 ...
# 2022-08-01   218.900000
# 2022-09-01   207.750000
# 2022-10-01   207.300000
# 2022-11-01   215.750000
# 2022-12-01   219.750000
#
# [96 rows x 1 columns]

# %%
# Destructuring initialization
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3, 1, figsize=(8,10)) # axs is a (1,2) nd-array

# First subplot
axs[0].plot(df_mensual["clientes_unicos"], label="clientes únicos")
axs[0].set_title('Clientes unicos')
axs[0].legend()
# Second subplot
axs[1].plot(df_mensual["suma_monto"], label="Monto mensual", c='orange')
axs[1].set_title("Monto en pesos")
axs[1].legend()
#third plot
axs[2].plot(dolar_df_mensual["media_venta"], label="Monto mensual", c='black')
axs[2].set_title("Valor medio dolar")
axs[2].legend()
# Global figure methods
plt.suptitle('Dolar historico')
plt.show()

# %% [markdown]
# Interpretacion en clase

# %%
df_mensual["monto_en_dolar"] =df_mensual["suma_monto"]/df_mensual["media_venta"]

# %%
# Destructuring initialization
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3, 1, figsize=(8,10)) # axs is a (1,2) nd-array

# First subplot
axs[0].plot(df_mensual["clientes_unicos"], label="clientes únicos")
axs[0].set_title('Clientes unicos')
axs[0].legend()
# Second subplot
axs[1].plot(df_mensual["monto_en_dolar"], label="Monto mensual", c='orange')
axs[1].set_title("Monto en dolares")
axs[1].legend()
#third plot
axs[2].plot(dolar_df_mensual["media_venta"], label="Monto mensual", c='black')
axs[2].set_title("Valor medio dolar")
axs[2].legend()
# Global figure methods
plt.suptitle('Dolar historico')
plt.show()

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(12,6)) # axs is a (1,2) nd-array

# First subplot
axs[0].plot(df_mensual["clientes_unicos"], label="clientes únicos")
axs[0].set_title('Clientes unicos')
axs[0].legend()
# Second subplot
axs[1].plot(df_mensual["monto_en_dolar"], label="Monto mensual en USD", c='orange')
axs[1].set_title("Monto en dolares")
axs[1].legend()

# %%
# !pwd
# Out:
# /Users/usuario/PycharmProjects/pythonProject5/UCEMA/06-examen/script

# %% [markdown]
# # Teoría (en menos de una carilla)
# 30.Teniendo en cuenta este dataset ¿Qué problema podrías resolver con Machine Learning?
#
# Dado que es una empresa que cobra préstamos y a esa dinero lo vuelve a colocar. Poder predecir cuanto dinero voy a cobrar mes a mes me permitiría tener una proyección clara de los fondos que voy a disponer para distintas estrategias financieras. Saber tambien cuanto dinero voy a cobrar los siguientes meses podría permitirme entnder a cuanto tiempo colocar el dinero, si lo coloco a un plazo muy largo y empiezo a cobrar menos, tal vez me quede sin dinero, si lo hago a muy corto plazo estimando que voy a cobrar mucho dinero podría también estar tomando un mala decisión.
#
# 31. En caso de embarcarse en una tarea de Machine Learning. Describa el proceso CRISPDM y expliquelo para este caso.
#
# El proceso CRISPDM tiene cómo etpas el entendimiento del negocio, el entendimiento de la data, la preparación o procesamiento, la evaluación y el deployment. En este caso habría que entender el valor económico de tener en claro que monto se va a cobrar para saber si justifica o no el modelo. Una vez entendido habría que buscar entender que columnas pueden favores a predecir cuanto se va a cobrar. ¿Los préstamos a cobrar están determinados por las condiciones macroeconómicas o también está determinado por cuantos préstamos se dieron los meses anteriores?. En caso de la preparación de la data en este caso habría que repetir eliminar los nulos y outliers. El modelo debería predecir una valor continuo, el monto a cobrar mensual. Para evaluarlo deberíamos hacer un back testing evaluando meses que conocemos sus resultados vs el valor del modelo. El deployment podría ser 1 vez al mes, no necesita ser real time.
#
# 32. ¿Qué decisión del negocio o tarea se podría automatizar o escalar? ¿Por qué?
#
# Podría automatizar la decisión de transferir al broker la cantidad de dinero a utilizar en estrategias y los plazos. Por otro lado cómo también tengo la data a nivel cliente podría predecir cuál es la probabilidad que un cliente individual pague el mes siguiente. Es analogo a los recibos totales pero a nivle individual. Podría automatizar un mensaje al cliente días previos al vencimiento de la cuota o un sistema de ranking para priorizar a cobradores de la empresa. Tendrían que llamar primer oa los clientes con mayor probabilidad de no pagar o menor probabilidad de pagar.
