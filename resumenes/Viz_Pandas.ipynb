# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd usuario/PycharmProjects/pythonProject5/UCEMA/05-viz
# Out:
# /Users/usuario/PycharmProjects/pythonProject5/UCEMA/05-viz

# %%
Data= pd.read_csv("datasets_plots/bar_chart_data.csv")

# %% [markdown]
# # **BAR CHART**

# %%
#tamaño
plt.figure(figsize=(5,3))
#tipo de grafico
plt.bar(x=Data["Brand"],height=Data["Cars Listings"],color="midnightblue")
#rotacion de las etiquetas del eje x
plt.xticks(rotation=45)
#tamaño de las etiquetas del eje y
plt.yticks(fontsize=12)
plt.title("Car listings by Brand",fontsize=16,fontweight='bold')
plt.ylabel("Car Listings", fontsize=14);

# %% [markdown]
# # **PIE CHART**

# %%
pie_data= pd.read_csv("datasets_plots/pie_chart_data.csv")
pie_data
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
#configurar la paleta de colores
sns.set_palette('colorblind')
#tamaño de la figura
plt.figure(figsize=(5,4))
plt.pie(pie_data["Number of Cars"],
   labels=pie_data["Engine Fuel Type"],
    autopct='%.2f%%',
    textprops={"size": "x-large",
              "rotation": "30"})
plt.legend()
plt.title("Cars by fuel type", fontsize="16",fontweight="bold");

# %% [markdown]
# # **STACKED BAR CHART**
# Los diagramas de barras apiladas representan diferentes grupos en la parte superior de 1 otro. El pico de la barra depende de la altura resultante de la mezcla de los resultados de los grupos. Va desde el fondo hasta el valor en lugar de ir desde cero hasta el valor.

# %%
stack_data=pd.read_csv("datasets_plots/stacked_area_chart_data.csv")
stack_data.head()
# Out:
#    Year   Gas  Petrol  Diesel  Other
# 0  1982     0      94       0      0
# 1  1983     0     347       0      0
# 2  1984   300       0     334      0
# 3  1985  1030    1184     984      0
# 4  1986   511     681    1066    340

# %%
plt.figure(figsize=(12,6))
sns.set_style("white")
labels=["Gas","Petrol","Diesel"]
plt.stackplot(stack_data["Year"],
              stack_data["Gas"],
              stack_data["Petrol"],
              stack_data["Diesel"],
              edgecolor='none',
              colors=["#FFB6C1","FF00FF","#9400D3"])
plt.xticks(stack_data["Year"], rotation=90)
plt.title("Popularity of engine fuel types(1982-2016)", fontsize=14, weight="bold")
plt.legend(labels=labels, loc='upper left')
sns.despine() #saca las lineas right y top
plt.show()

# %% [markdown]
# # **LINE CHARTS**
# Representan relación entre X e Y

# %%
line_chart=pd.read_csv("datasets_plots/line_chart_data.csv")
line_chart
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
line_chart["date"]=pd.to_datetime(line_chart["Date"])
line_chart["date"]
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 2865   2010-12-27
# 2866   2010-12-28
# 2867   2010-12-29
# 2868   2010-12-30
# 2869   2010-12-31
# Name: date, Length: 2870, dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,8))
plt.plot(line_chart["date"],line_chart["GSPC500"])
plt.plot(line_chart["date"],line_chart["FTSE100"])
plt.title("S&P vs FTSE return(2000-2010)",fontsize=14,weight="bold")
plt.legend(labels=["Date","S&P 500","FTSE 100"], loc="upper left")
plt.show()

# %%
df_2009= line_chart[(line_chart.date>="2009-07-01") & (line_chart.date<="2009-12-31")]
df_2009
# Out:
#             Date   GSPC500   FTSE100       date
# 2477    7/1/2009 -0.006827 -0.010433 2009-07-01
# 2478    7/2/2009  0.000456  0.021533 2009-07-02
# 2479    7/3/2009  0.000000 -0.024512 2009-07-03
# 2480    7/6/2009 -0.029276  0.000472 2009-07-06
# 2481    7/7/2009  0.004842 -0.009773 2009-07-07
# ...          ...       ...       ...        ...
# 2604  12/25/2009  0.000000  0.000000 2009-12-25
# 2605  12/28/2009  0.005753  0.000000 2009-12-28
# 2606  12/29/2009  0.000905  0.000000 2009-12-29
# 2607  12/30/2009 -0.002676  0.006516 2009-12-30
# 2608  12/31/2009  0.000951 -0.004542 2009-12-31
#
# [132 rows x 4 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot(df_2009["date"],df_2009["GSPC500"],color="midnightblue")
plt.plot(df_2009["date"],df_2009["FTSE100"],color="crimson")
plt.title("S&P vs FTSE return(2000-2010)",fontsize=14,weight="bold")
plt.legend(labels=["Date","S&P 500","FTSE 100"], loc="upper left",fontsize="large")
plt.show()

# %% [markdown]
# # **HISTOGRAMA**
# Un histograma se utiliza básicamente para representar los datos proporcionados en forma de algunos grupos. Es un método preciso para la representación gráfica de la distribución de datos numéricos. sobre la frecuencia.

# %%
hist_data=pd.read_csv("datasets_plots/histogram_data.csv")
hist_data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
plt.figure(figsize=(9,6))
sns.set_style("white")
plt.hist(hist_data["Price"], bins=8, color="#008080")
plt.title("Distribution of Real State Prices", fontsize=14, weight="bold")
plt.xlabel("Price")
sns.despine()
plt.show()

# %% [markdown]
# # **SCATTER PLOTS**
# Los diagramas de dispersión se utilizan para observar la relación entre las variables y utilizan puntos para representar la relación entre ellas. Los diagramas de dispersión se usan ampliamente para representar la relación entre variables y cómo el cambio en uno afecta al otro.

# %%
scatter_data= pd.read_csv("datasets_plots/scatter_data.csv")
scatter_data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
plt.figure(figsize=(9,6))
scatter=plt.scatter(scatter_data["Area (ft.)"],
            scatter_data["Price"],
           alpha=0.6,
           c=scatter_data["Building Type"],
           cmap='viridis')
plt.title("Area V/S Price", fontsize=14, weight="bold")
plt.xlabel("Area")
plt.ylabel("Price")
plt.legend(*scatter.legend_elements(), loc="upper left", title="Building Type")
plt.show()

# %% [markdown]
# # **REGRESSION PLOTS**
# Los gráficos de regresión, como sugiere el nombre, crean una línea de regresión entre 2 parámetros y ayudan a visualizar sus relaciones lineales. Podemos trazar gráficos de regresión usando dos métodos: sns.regplot() sns.lmplot() Veamos ambos en detalle.

# %%
regression_data=pd.read_csv("datasets_plots/scatter_plot_ii.csv")
regression_data.head()
# Out:
#    Budget  Sales
# 0   337.1   22.1
# 1   128.9   10.4
# 2   132.4    9.3
# 3   251.3   18.5
# 4   250.0   12.9

# %%
plt.figure(figsize=(9,6))
sns.regplot(x="Budget",
            y="Sales",
            data= regression_data,
            scatter_kws={'color':'k'},
            line_kws={'color':'red'})
plt.title("Effect of Budget on Sales", fontsize=14, weight="bold")
plt.show()

# %%
regression_data_2= pd.read_csv("datasets_plots/scatter_data.csv")
regression_data_2
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
sns.lmplot(x="Area (ft.)",
          y="Price",
          data=regression_data_2,
          scatter_kws={'color':'k'},
          line_kws={'color':'red'},
          height=6)
sns.set()
plt.title("Effect of Area on Price", fontsize=14, weight="bold")
plt.show()

# %% [markdown]
# # **BAR & LINE CHART**

# %%
combined_data= pd.read_csv("datasets_plots/bar_line_chart_data.csv")
combined_data.head()
# Out:
#    Year  Python Users  Participants
# 0  2012         0.149           798
# 1  2013         0.133          1880
# 2  2014         0.195          3285
# 3  2015         0.303          2800
# 4  2016         0.458          2895

# %%
from matplotlib.ticker import PercentFormatter
sns.set_style("white")
fig, ax= plt.subplots(figsize=(10,7))
ax.bar(combined_data["Year"],
      combined_data["Participants"],
      color='k')
ax.set_ylabel("Number of Participants", fontsize=14, weight="bold")
ax1= ax.twinx()
ax1.set_ylim(0,1)
ax1.yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
ax1.plot(combined_data["Year"],
      combined_data["Python Users"],
      color='#b60000',
      marker='D')
ax1.set_ylabel("Python Users", fontsize=14, weight="bold")
ax.set_title("KD Nuggets Survey Python Users", fontsize=14, weight="bold")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image
plt.style.use('classic')
# %matplotlib inline

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)

# %%
plt.scatter(x, y)
# Calling plt.title() gets translated into this one line: gca().set_title("Stateful Example")
plt.title('Stateful Example');

# %%
# Take object references into variables
fig = plt.figure()
ax = plt.axes()
# Call plotting function as Axes method
scatter = ax.scatter(x, y)
ax.set_title('Stateless Example')
# Out:
# Text(0.5, 1.0, 'Stateless Example')

# %% [markdown]
# ## <a name="modifying_ticks"></a> Modifying x or y ticks
# Scales
# * linear
# * log
# * symlog
# * function
# * funtionlog

# %%
ax = plt.axes(xscale='symlog', yscale='log')
ax.grid()

# %% [markdown]
# ### Hiding Ticks and Labels

# %%
ax = plt.axes()
ax.plot(np.random.rand(50))
#saca los numeros en la recta y
ax.yaxis.set_major_locator(plt.NullLocator())
#saca los numeros en la recta x
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %% [markdown]
# ### Reducing or Increasing the Number of Ticks

# %% [markdown]
# sharex: es para compartir los valores del eje x.
# sharey: es para compartir los valores del eje y

# %% [markdown]
# #fig = plt.subplots(4,4) -> genera graficos
# #ax = plt.subplots(sharex=False, sharey=True) -> sirve para no repetir los numeros de la recta

# %%
fig, ax = plt.subplots(4, 2, sharex=True, sharey=True)

# %% [markdown]
# Pone tres ticks por eje del subplot
# `plt.MaxNLocator()` -> divide la recta por la cantidad dicha ejemplo si se escribe 2 se divide en 2

# %%
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))
fig

# %% [markdown]
# Pone los ticks con los saltos en la escala indicados

# %%
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MultipleLocator(0.3))
    axi.yaxis.set_major_locator(plt.MultipleLocator(0.3))
fig

# %% [markdown]
# ## Setting labels as %

# %%
import matplotlib.ticker as mtick
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %% [markdown]
# ## Creating custom labels
# Creación de etiquetas personalizadas Imagine que quisiéramos crear una función personalizada para formatear etiquetas donde convertiríamos miles a K y millones a MM. Usaríamos la clase FuncFormatter de matplotlib.ticker de la siguiente manera:

# %%
def abreviate_thousands_and_millions(value, tick_number):
    if value // 1000000:
        new_value=value//1000000
        return '${:,.1f}MM'.format(new_value)
    elif value // 1000:
        new_value=value//1000
        return '${:,.1f}K'.format(new_value)
    else:
        new_value=value
    return '${:,.1f}'.format(new_value)

# %%
x = np.random.randint(low=200, high=10000000, size=50)
y = x + np.random.randint(1, 1000000, size=x.size)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y)
ax.xaxis.set_major_formatter(plt.FuncFormatter(abreviate_thousands_and_millions))
ax.yaxis.set_major_formatter(plt.FuncFormatter(abreviate_thousands_and_millions))

# %% [markdown]
# ## Creación de múltiples parcelas con diferentes arreglos

# %%
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

# %%
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

ax1.set_title('Random Line', fontsize=14)
ax1.plot(np.random.rand(50))
x = np.random.randint(low=200, high=10000000, size=50)
y = x + np.random.randint(1, 1000000, size=x.size)
ax2.scatter(x=x, y=y)
ax3.hist(x, bins=40)
# Out:
# (array([3., 0., 2., 0., 0., 3., 4., 0., 3., 0., 1., 1., 3., 1., 0., 1., 2.,
#         0., 0., 3., 1., 4., 3., 0., 1., 0., 0., 1., 0., 2., 3., 1., 1., 0.,
#         0., 1., 1., 2., 1., 1.]),
#  array([  40094.  ,  288159.45,  536224.9 ,  784290.35, 1032355.8 ,
#         1280421.25, 1528486.7 , 1776552.15, 2024617.6 , 2272683.05,
#         2520748.5 , 2768813.95, 3016879.4 , 3264944.85, 3513010.3 ,
#         3761075.75, 4009141.2 , 4257206.65, 4505272.1 , 4753337.55,
#         5001403.  , 5249468.45, 5497533.9 , 5745599.35, 5993664.8 ,
#         6241730.25, 6489795.7 , 6737861.15, 6985926.6 , 7233992.05,
#         7482057.5 , 7730122.95, 7978188.4 , 8226253.85, 8474319.3 ,
#         8722384.75, 8970450.2 , 9218515.65, 9466581.1 , 9714646.55,
#         9962712.  ]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# ## Fuente creciente para todas las parcelas
# A veces, la fuente de la trama puede ser muy pequeña, lo que dificulta la lectura de títulos y etiquetas. Hay una manera muy simple de configurar la fuente para todos los gráficos a un cierto tamaño con plt.rc, ajusta la configuración de tiempo de ejecución de Matplolib:

# %%
import matplotlib
font = {'family' : 'normal',
        'size'   : 14}
matplotlib.rc('font', **font)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y)
ax.set_title('Bigger Font')
# Out:
# Text(0.5, 1.0, 'Bigger Font')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Configuración de estilos de trazado

# %%
plt.style.use('ggplot')
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y)
ax.set_title('ggplot')
# Out:
# Text(0.5, 1.0, 'ggplot')

# %%
plt.style.use('seaborn')
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y)
ax.set_title('seaborn')
# Out:
# Text(0.5, 1.0, 'seaborn')
